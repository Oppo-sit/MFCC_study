# %%
import pandas as pd

# %%
# 한글 포함된 파일은 encoding 설정 필요 : https://zephyrus1111.tistory.com/39
## cp949 : euc-kr의 확장된 인코더
csv_4th = pd.read_csv('C:/Users/RestJSM/librosa/data/emotion_dataset/4th_year.csv', encoding='cp949')

# %%
csv_4th.shape
# Out:
# (14606, 15)

# %%
# 데이터 정렬 참조 : https://hogni.tistory.com/6
csv_4th_ascending = csv_4th.sort_values(by='상황')
csv_4th_ascending
# Out:
#                         wav_id  \
# 0     5e258fd1305bcf3ad153a6a4
# 8190  5e3cdc4c7995ef170fc0fef9
# 8188  5e3cdc0d33e9ad176cc9bd41
# 8176  5e3cd7eb7995ef170fc0feee
# 8175  5e3cd7d405fef317e874cba9
# ...                        ...
# 9486  5e41655d0b3f160367c207f8
# 9481  5e4163eb9329cb02ef38a70f
# 9480  5e42404c0b3f160367c208fb
# 2070  5e35b47ebacf60088a5ad7fd
# 3904  5e368b5833e9ad176cc9a8c5
#
#                                                     발화문     상황    1번 감정  \
# 0                                      어, 청소 니가 대신 해 줘!  anger  Neutral
# 8190  어 해본 적 있는데 아 오늘 오면 또 해봐야겠어. 아 이렇게는 못 이렇게는 같이 못...  anger    Angry
# 8188                                   한시간 넘게 기다린 거 같애.  anger    Angry
# 8176     어. 그래도 좀 고쳐서 같이 살고 싶은데. 그래도 그거 빼고는 진짜 괜찮은 애거든.  anger  Sadness
# 8175   어. 고등학교 동창이야. 그래서 같이 하기 시작했는데, 아, 이렇게 더러울 줄 몰랐어.  anger    Angry
# ...                                                 ...    ...      ...
# 9486  권태기가 온 거 같다고 시간을 갖자고 하더라구. 그런데 새로운 여자가 생겼어. 왜 ...    sad  Sadness
# ...

# %%
# 필터링 및 열 추출
## 참조 1 : https://wikidocs.net/46753 (필터)
## 참조 2 : https://blog.naver.com/PostView.nhn?blogId=rising_n_falling&logNo=221622971970 (행, 열 추출)
csv_4th_filt = csv_4th.loc[csv_4th['상황'] == 'anger']
csv_4th_id = csv_4th_filt.loc[:, ['wav_id', '상황']]
csv_4th_id
# Out:
#                          wav_id     상황
# 0      5e258fd1305bcf3ad153a6a4  anger
# 1      5e258fe2305bcf3ad153a6a5  anger
# 2      5e258ff5305bcf3ad153a6a6  anger
# 3      5e25902f305bcf3ad153a6a9  anger
# 6      5e27fb575807b852d9e01595  anger
# ...                         ...    ...
# 14601  5e53d6067bef803b4851dfc6  anger
# 14602  5e53d61cc38c123b9ec6dde6  anger
# 14603  5e53d6332a2d173b73a03210  anger
# 14604  5e53d659963e443aee02b7d0  anger
# 14605  5e53d6778849ac3aacea576f  anger
#
# [5213 rows x 2 columns]

# %%
# 행/열, 데이터 선택 참조 : https://codetorial.net/pandas/selection.html
csv_4th_id.iloc[0][0]
# Out:
# '5e258fd1305bcf3ad153a6a4'

# %%
#문자로 데이터 찾기 : https://seong6496.tistory.com/127
csv_4th_id[csv_4th_id['wav_id'].str.contains('5e53d659963e443aee02b7d0')].iloc[0][1]
# Out:
# 'anger'
